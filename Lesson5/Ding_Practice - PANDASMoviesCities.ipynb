# %% [markdown]
# # PANDAS PRACTICE 2

# %% [markdown]
# ### In this practice we will look at weather data from  various cities and see how groupby can be used to run some analytics. Add code cells where applicable.

# %%
import pandas as pd

# %% [markdown]
# ####  Question 1
#
# #### Let us explore the movie dataset
#
# 1. Load in the IMDB movies dataset
# 2. Display the top 5 and last 5 movies and columns
# 3. Display information about the columns. What are the datatypes?
# 4. Append the dataframe to itself
# 5. Display the shape of the dataframe
# 6. Remove the duplicates
# 7. Confirm that the shape has been modified

# %%
# Load in the IMDB movies dataset
df=pd.read_csv("IMDB-Movie-Data.csv")
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
# Display the top 5 and last 5 movies and columns
df.head(5)
df.tail(5)
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %%
# Display information about the columns. What are the datatypes?
df.dtypes
#df.describe()
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
# Append the dataframe to itself
# Notice: df.apppend method has been deprecated. Use concat instead.
# !python --version
df_append = pd.concat([df, df])
df_append
# Out:
# Python 3.11.7
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
# Display the shape of the dataframe
df_append.shape
# Out:
# (2000, 12)

# %%
# Remove the duplicates
df_no_duplicates = df_append.drop_duplicates()
df_no_duplicates
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
# Confirm that the shape has been modified, it should be 1000 rows × 12 columns
df_no_duplicates.shape
# Out:
# (1000, 12)

# %% [markdown]
# #### Question 2
#
# #### Let us explore another dataset. This time the weather dataset
#
# 1. Create the data frame from the given csv file
# 2. Display the first 10 rows
# 3. Display the last 5 rows
# 4. Display the datatypes
# 5. Display statistics for a numerical column

# %%
# Create the data frame from the given csv file
import pandas as pd
df2=pd.read_csv("weather_by_cities.csv")
df2.shape
# Out:
# (12, 5)

# %%
# Display the first 10 rows
df2.head(10)
# Out:
#         day      city  temperature  windspeed   event
# 0  1/1/2017  new york           32          6    Rain
# 1  1/2/2017  new york           36          7   Sunny
# 2  1/3/2017  new york           28         12    Snow
# 3  1/4/2017  new york           33          7   Sunny
# 4  1/1/2017    mumbai           90          5   Sunny
# 5  1/2/2017    mumbai           85         12     Fog
# 6  1/3/2017    mumbai           87         15     Fog
# 7  1/4/2017    mumbai           92          5    Rain
# 8  1/1/2017     paris           45         20   Sunny
# 9  1/2/2017     paris           50         13  Cloudy

# %%
# Display the last 5 rows
df2.tail(5)
# Out:
#          day    city  temperature  windspeed   event
# 7   1/4/2017  mumbai           92          5    Rain
# 8   1/1/2017   paris           45         20   Sunny
# 9   1/2/2017   paris           50         13  Cloudy
# 10  1/3/2017   paris           54          8  Cloudy
# 11  1/4/2017   paris           42         10  Cloudy

# %%
# Display the datatypes
df2.dtypes
# Out:
# day            object
# city           object
# temperature     int64
# windspeed       int64
# event          object
# dtype: object

# %%
# Display statistics for a numerical column
df2.describe()
# Out:
#        temperature  windspeed
# count    12.000000  12.000000
# mean     56.166667  10.000000
# std      25.044808   4.572646
# min      28.000000   5.000000
# 25%      35.250000   6.750000
# 50%      47.500000   9.000000
# 75%      85.500000  12.250000
# max      92.000000  20.000000

# %% [markdown]
# #### Question 3
#
# For this dataset let us determine the following. We will explore splitting your dataset in smaller groups and then applying an operation (such as min or max) to get aggregate result is called Split-Apply-Combine approach.

# %%
# Groupby city and print the data for all the groups
# Get the data group for Mumbai
# Get the max temp for all cities
# What is the avarage temperature and windspeed
# Display all the analytics for the data
# Let us do a rudimentary plot. See code below
'''
# %matplotlib inline # load matplotlib
variable.plot()

'''

import matplotlib as plt

# %%
# 1. Groupby city and print the data for all the groups
grouped_by_city = df2.groupby('city')
grouped_by_city.groups.keys()
# Out:
# dict_keys(['mumbai', 'new york', 'paris'])

# %%
 df2[df2["city"]=="paris"]
    
    
for row, index in df.iterrows()
    if row["city"] == "paris"
    print(row)
# Out:
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
# 2. Get the data group for Mumbai
mumbai_data = grouped_by_city.get_group('mumbai')
mumbai_data
# Out:
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain

# %%
# 3. Get the max temp for all cities
max_temp_by_city = grouped_by_city['temperature'].max()
max_temp_by_city
# Out:
# city
# mumbai      92
# new york    36
# paris       54
# Name: temperature, dtype: int64

# %%
# 4. What is the average temperature and windspeed
average_temp = df2['temperature'].mean()
average_windspeed = df2['windspeed'].mean()

print("average temperature is "+str(average_temp))
print("average windspeed is "+str(average_windspeed))
# Out:
# average temperature is 56.166666666666664
# average windspeed is 10.0

# %%
df2.describe()
# Out:
#        temperature  windspeed
# count    12.000000  12.000000
# mean     56.166667  10.000000
# std      25.044808   4.572646
# min      28.000000   5.000000
# 25%      35.250000   6.750000
# 50%      47.500000   9.000000
# 75%      85.500000  12.250000
# max      92.000000  20.000000

# %%
# 6. Rudimentary plot of temperature
# Enabling inline matplotlib
# %matplotlib inline
temperature_plot = df2['temperature'].plot()

# %%
temperature_plot = df2[df2["city"]=='new york']['temperature'].plot()
