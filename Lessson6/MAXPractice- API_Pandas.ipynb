# %% [markdown]
# # Practice: 7 Day Forecast
#
# ## The Problem
#
# For this assignment, you input a location and then display the **current conditions** and the **7 day weather forecast** for that location.
#
# To accomplish this, you will need a Weather API and a Geocoding API. I suggest using the example from lesson 10. OpenWeatherMap is a free service and Open street maps https://nominatim.openstreetmap.org/search Their OneCall API should be excatly what you need: https://openweathermap.org/api/one-call-api  The focus of this assignment is loading the 7-day forecast int a data frame and the manipulation of the data frame itself.
#
#
# ### Requirements:
#
# - Display all temperatures as integer values ( I don't want to see 34.67) in degrees Fahrenheit (Imperial units).
# - Make sure to show the weather icon for the current conditions: https://openweathermap.org/weather-conditions#How-to-get-icon-URL See example here, for code `10d`: http://openweathermap.org/img/wn/10d@2x.png
# - The 7 day forecast should display the Day of the week (Monday, Tuesday, etc...) plus the low and high temperatures for that day.
#
#
# ### Screenshot of an example run:
#
# ![https://i.imgur.com/MiSpxaT.png](https://i.imgur.com/MiSpxaT.png)
#
#
# HINTS and ADVICE:
#
# - Use the **problem simplification approach** solve a simpler problem and add complexity as you figure things out.
# - Hard-code a location. e.g. Syracuse, NY
# - The OneCall API should be exactly what you need: https://openweathermap.org/api/one-call-api
# - For the `current conditions`, we only need the description weather icon and current temperature. Get that working next.
# - Next work on getting the 7-day to display in a data frame.
# - Next work on setting the 7-day to display EXACTLY like the output. There are several approaches:
#    - You could iterate over the API output building another list of dict with exactly the values required and then displaying that in a data frame.
#    - You could load the API output into a dataframe then use `to_records()` to iterate over the dataframe to build another data frame
#    - You could try to manipulate the dataframe with the `apply()` method an a lambda (inline function). This is probably the least amount of code but the most difficult to accomplish.
# - Once everything above works, introduce IPython interact and allow for the input of any location. You are done!

# %% [markdown]
# ## Part 1: Problem Analysis
#
# Inputs:
#
# ```
# TODO: Inputs
#
# ```
#
# Outputs:
#
# ```
# TODO: Outputs
#
#
# ```
#
# Algorithm (Steps in Program):
#
# ```
# TODO:Steps Here
#
#
#
# ```

# %% [markdown]
# ## Part 2: Code Solution
#
# Write your code in several cells, but place the complete, final working copy of your code solution within this single cell below. Only the within this cell will be considered your solution. Any imports or user-defined functions should be copied into this cell.
#
# Use the key "67f9d45c32dd086df27f2b7a90370a8e"

# %%
import requests
import time
import pandas as pd
from pandas import json_normalize
from IPython.display import display, HTML
from ipywidgets import interact_manual

def geocode(location):
    query_string = {'q' : location, 'format': 'json'}
    headers = { "user-agent" : "ist300 example auramnar@syr.edu" }
    url='https://nominatim.openstreetmap.org/search'
    response = requests.get(url, params = query_string, headers=headers)
    response.raise_for_status()
    geodata = response.json()
    lat=geodata[0]['lat']
    lon=geodata[0]['lon']
    return lat, lon

def calculateDay (timeU):
    day = time.strftime('%A', time.localtime(timeU))
    return day
def temp (temperature):
    fah = (temperature - 273.15) * 1.8 + 32
    fah=int(fah)
    return fah
APIkey = "67f9d45c32dd086df27f2b7a90370a8e"

display(HTML("<h1>Temperature Forecast</h1>"))
@interact_manual(location="")
def main(location):
    lat, lon = geocode(location)
    url = f'https://api.openweathermap.org/data/2.5/onecall?lat={lat}&lon={lon}&exclude=hourly,minutely,alerts&appid={APIkey}'
    response = requests.get(url)
    data=response.json()
    currentweather = data['current']['temp']
    currentweather=temp(currentweather)
    condition = data['current']['weather'][0]['description']
    print(f'{condition} with a temperature of {currentweather}F')
    daily = json_normalize(data['daily'])
    weatherFrame = pd.DataFrame(daily,columns=['dt','temp.min','temp.max'])
    weatherFrame = weatherFrame.rename(columns={'dt': 'Date', 'temp.min':'Low','temp.max':'High'})
    lol = weatherFrame['Date'].apply(calculateDay)
    tempLow = weatherFrame['Low'].apply(temp)
    tempHigh = weatherFrame['High'].apply(temp)
    weatherFrame['Date']=lol
    weatherFrame['Low']=tempLow
    weatherFrame['High']=tempHigh
    return weatherFrame
# Out:
# <h1>Temperature Forecast</h1>
# interactive(children=(Text(value='', description='location'), Button(description='Run Interact', style=ButtonS…
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
lat, lon = 40, -73
url = f'https://api.openweathermap.org/data/2.5/onecall?lat={lat}&lon={lon}&appid={APIkey}'
response = requests.get(url)
data=response.json()
data
# Out:
# {'lat': 40,
#  'lon': -73,
#  'timezone': 'Etc/GMT+5',
#  'timezone_offset': -18000,
#  'current': {'dt': 1709082965,
#   'sunrise': 1709033358,
#   'sunset': 1709073639,
#   'temp': 282.83,
#   'feels_like': 278.26,
#   'pressure': 1015,
#   'humidity': 94,
#   'dew_point': 281.91,
#   'uvi': 0,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 13.64,
#   'wind_deg': 189,
#   'wind_gust': 23,
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'rain': {'1h': 1.26}},
#  'minutely': [{'dt': 1709083020, 'precipitation': 1.1983},
#   {'dt': 1709083080, 'precipitation': 1.1317},
#   {'dt': 1709083140, 'precipitation': 1.0651},
#   {'dt': 1709083200, 'precipitation': 0.9985},
#   {'dt': 1709083260, 'precipitation': 0.9718},
#   {'dt': 1709083320, 'precipitation': 0.945},
#   {'dt': 1709083380, 'precipitation': 0.9182},
#   {'dt': 1709083440, 'precipitation': 0.8914},
#   {'dt': 1709083500, 'precipitation': 0.8647},
#   {'dt': 1709083560, 'precipitation': 0.8647},
#   {'dt': 1709083620, 'precipitation': 0.8647},
#   {'dt': 1709083680, 'precipitation': 0.8647},
#   {'dt': 1709083740, 'precipitation': 0.8647},
#   {'dt': 1709083800, 'precipitation': 0.8647},
#   {'dt': 1709083860, 'precipitation': 0.9993},
#   {'dt': 1709083920, 'precipitation': 1.1339},
#   {'dt': 1709083980, 'precipitation': 1.2685},
#   {'dt': 1709084040, 'precipitation': 1.4031},
#   {'dt': 1709084100, 'precipitation': 1.5376},
#   {'dt': 1709084160, 'precipitation': 1.6402},
#   {'dt': 1709084220, 'precipitation': 1.7428},
#   {'dt': 1709084280, 'precipitation': 1.8453},
#   {'dt': 1709084340, 'precipitation': 1.9479},
#   {'dt': 1709084400, 'precipitation': 2.0505},
#   {'dt': 1709084460, 'precipitation': 1.9479},
#   {'dt': 1709084520, 'precipitation': 1.8453},
#   {'dt': 1709084580, 'precipitation': 1.7428},
#   {'dt': 1709084640, 'precipitation': 1.6402},
#   {'dt': 1709084700, 'precipitation': 1.5376},
#   {'dt': 1709084760, 'precipitation': 1.6402},
#   {'dt': 1709084820, 'precipitation': 1.7428},
#   {'dt': 1709084880, 'precipitation': 1.8453},
#   {'dt': 1709084940, 'precipitation': 1.9479},
#   {'dt': 1709085000, 'precipitation': 2.0505},
#   {'dt': 1709085060, 'precipitation': 2.2719},
#   {'dt': 1709085120, 'precipitation': 2.4933},
#   {'dt': 1709085180, 'precipitation': 2.7147},
#   {'dt': 1709085240, 'precipitation': 2.9362},
#   {'dt': 1709085300, 'precipitation': 3.1576},
#   {'dt': 1709085360, 'precipitation': 2.8812},
#   {'dt': 1709085420, 'precipitation': 2.6048},
#   {'dt': 1709085480, 'precipitation': 2.3284},
#   {'dt': 1709085540, 'precipitation': 2.052},
#   {'dt': 1709085600, 'precipitation': 1.7756},
#   {'dt': 1709085660, 'precipitation': 1.728},
#   {'dt': 1709085720, 'precipitation': 1.6804},
#   {'dt': 1709085780, 'precipitation': 1.6328},
#   {'dt': 1709085840, 'precipitation': 1.5852},
#   {'dt': 1709085900, 'precipitation': 1.5376},
#   {'dt': 1709085960, 'precipitation': 1.4964},
#   {'dt': 1709086020, 'precipitation': 1.4552},
#   {'dt': 1709086080, 'precipitation': 1.414},
#   {'dt': 1709086140, 'precipitation': 1.3728},
#   {'dt': 1709086200, 'precipitation': 1.3315},
#   {'dt': 1709086260, 'precipitation': 1.215},
#   {'dt': 1709086320, 'precipitation': 1.0984},
#   {'dt': 1709086380, 'precipitation': 0.9819},
#   {'dt': 1709086440, 'precipitation': 0.8653},
#   {'dt': 1709086500, 'precipitation': 0.7488},
#   {'dt': 1709086560, 'precipitation': 0.7287}],
#  'hourly': [{'dt': 1709082000,
#    'temp': 282.83,
#    'feels_like': 278.26,
#    'pressure': 1015,
#    'humidity': 94,
#    'dew_point': 281.91,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 13.64,
#    'wind_deg': 189,
#    'wind_gust': 23,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.44,
#    'rain': {'1h': 0.13}},
#   {'dt': 1709085600,
#    'temp': 282.76,
#    'feels_like': 278.61,
#    'pressure': 1015,
#    'humidity': 94,
#    'dew_point': 281.84,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 11.15,
#    'wind_deg': 198,
#    'wind_gust': 19.2,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 0.56,
#    'rain': {'1h': 1.78}},
#   {'dt': 1709089200,
#    'temp': 282.69,
#    'feels_like': 278.27,
#    'pressure': 1015,
#    'humidity': 94,
#    'dew_point': 281.77,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 7638,
#    'wind_speed': 12.46,
#    'wind_deg': 204,
#    'wind_gust': 23.5,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.84,
#    'rain': {'1h': 0.27}},
#   {'dt': 1709092800,
#    'temp': 282.59,
#    'feels_like': 277.96,
#    'pressure': 1015,
#    'humidity': 94,
#    'dew_point': 281.67,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 13.49,
#    'wind_deg': 193,
#    'wind_gust': 22.2,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 1.06}},
#   {'dt': 1709096400,
#    'temp': 282.61,
#    'feels_like': 277.8,
#    'pressure': 1014,
#    'humidity': 94,
#    'dew_point': 281.69,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 14.64,
#    'wind_deg': 192,
#    'wind_gust': 27.4,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 1}},
#   {'dt': 1709100000,
#    'temp': 282.85,
#    'feels_like': 277.95,
#    'pressure': 1013,
#    'humidity': 96,
#    'dew_point': 282.18,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 5745,
#    'wind_speed': 15.81,
#    'wind_deg': 190,
#    'wind_gust': 25.5,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 1.5}},
#   {'dt': 1709103600,
#    'temp': 282.87,
#    'feels_like': 278.03,
#    'pressure': 1013,
#    'humidity': 98,
#    'dew_point': 282.59,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 1265,
#    'wind_speed': 15.46,
#    'wind_deg': 186,
#    'wind_gust': 25.91,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 2}},
#   {'dt': 1709107200,
#    'temp': 282.81,
#    'feels_like': 277.96,
#    'pressure': 1012,
#    'humidity': 98,
#    'dew_point': 282.46,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 3905,
#    'wind_speed': 15.35,
#    'wind_deg': 187,
#    'wind_gust': 26.4,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 3.19}},
#   {'dt': 1709110800,
#    'temp': 283.29,
#    'feels_like': 282.89,
#    'pressure': 1011,
#    'humidity': 97,
#    'dew_point': 282.8,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 9892,
#    'wind_speed': 15.81,
#    'wind_deg': 189,
#    'wind_gust': 26.6,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 1.44}},
#   {'dt': 1709114400,
#    'temp': 283.07,
#    'feels_like': 278.3,
#    'pressure': 1011,
#    'humidity': 98,
#    'dew_point': 282.72,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 6222,
#    'wind_speed': 15.46,
#    'wind_deg': 189,
#    'wind_gust': 26.71,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 1.31}},
#   {'dt': 1709118000,
#    'temp': 283.3,
#    'feels_like': 282.93,
#    'pressure': 1010,
#    'humidity': 98,
#    'dew_point': 282.96,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 8673,
#    'wind_speed': 16.84,
#    'wind_deg': 191,
#    'wind_gust': 27.8,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 0.88}},
#   {'dt': 1709121600,
#    'temp': 283.03,
#    'feels_like': 278.12,
#    'pressure': 1010,
#    'humidity': 98,
#    'dew_point': 282.75,
#    'uvi': 0.02,
#    'clouds': 100,
#    'visibility': 491,
#    'wind_speed': 16.32,
#    'wind_deg': 190,
#    'wind_gust': 28.1,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 1,
#    'rain': {'1h': 0.63}},
#   {'dt': 1709125200,
#    'temp': 283.46,
#    'feels_like': 283.08,
#    'pressure': 1010,
#    'humidity': 97,
#    'dew_point': 282.95,
#    'uvi': 0.07,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 17.62,
#    'wind_deg': 199,
#    'wind_gust': 27.51,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.92,
#    'rain': {'1h': 0.19}},
#   {'dt': 1709128800,
#    'temp': 283,
#    'feels_like': 278.11,
#    'pressure': 1010,
#    'humidity': 97,
#    'dew_point': 282.51,
#    'uvi': 0.22,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 16.13,
#    'wind_deg': 200,
#    'wind_gust': 25.51,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 1,
#    'rain': {'1h': 0.5}},
#   {'dt': 1709132400,
#    'temp': 282.79,
#    'feels_like': 277.9,
#    'pressure': 1010,
#    'humidity': 96,
#    'dew_point': 282.19,
#    'uvi': 0.5,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 15.56,
#    'wind_deg': 198,
#    'wind_gust': 26.5,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 1,
#    'rain': {'1h': 0.63}},
#   {'dt': 1709136000,
#    'temp': 283.28,
#    'feels_like': 282.86,
#    'pressure': 1009,
#    'humidity': 96,
#    'dew_point': 282.73,
#    'uvi': 0.37,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 17.06,
#    'wind_deg': 198,
#    'wind_gust': 28.91,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 1,
#    'rain': {'1h': 0.38}},
#   {'dt': 1709139600,
#    'temp': 283.19,
#    'feels_like': 282.76,
#    'pressure': 1008,
#    'humidity': 96,
#    'dew_point': 282.59,
#    'uvi': 0.26,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 17.62,
#    'wind_deg': 193,
#    'wind_gust': 29.32,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 1,
#    'rain': {'1h': 0.19}},
#   {'dt': 1709143200,
#    'temp': 283.62,
#    'feels_like': 283.2,
#    'pressure': 1006,
#    'humidity': 95,
#    'dew_point': 282.87,
#    'uvi': 0.65,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 18.49,
#    'wind_deg': 194,
#    'wind_gust': 30.61,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.8},
#   {'dt': 1709146800,
#    'temp': 283.84,
#    'feels_like': 283.42,
#    'pressure': 1005,
#    'humidity': 94,
#    'dew_point': 282.79,
#    'uvi': 0.3,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 19.25,
#    'wind_deg': 192,
#    'wind_gust': 32.8,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.2},
#   {'dt': 1709150400,
#    'temp': 283.73,
#    'feels_like': 283.3,
#    'pressure': 1005,
#    'humidity': 94,
#    'dew_point': 282.83,
#    'uvi': 0.36,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 18.1,
#    'wind_deg': 197,
#    'wind_gust': 32.41,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.4,
#    'rain': {'1h': 0.13}},
#   {'dt': 1709154000,
#    'temp': 283.18,
#    'feels_like': 282.75,
#    'pressure': 1005,
#    'humidity': 96,
#    'dew_point': 282.53,
#    'uvi': 0.1,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 16.7,
#    'wind_deg': 197,
#    'wind_gust': 30.71,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.48,
#    'rain': {'1h': 0.38}},
#   {'dt': 1709157600,
#    'temp': 283.92,
#    'feels_like': 283.51,
#    'pressure': 1004,
#    'humidity': 94,
#    'dew_point': 282.9,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 18,
#    'wind_deg': 202,
#    'wind_gust': 30.01,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.64,
#    'rain': {'1h': 0.56}},
#   {'dt': 1709161200,
#    'temp': 283.84,
#    'feels_like': 283.45,
#    'pressure': 1003,
#    'humidity': 95,
#    'dew_point': 283.03,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 18.91,
#    'wind_deg': 196,
#    'wind_gust': 30.42,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.92,
#    'rain': {'1h': 0.13}},
#   {'dt': 1709164800,
#    'temp': 283.87,
#    'feels_like': 283.48,
#    'pressure': 1003,
#    'humidity': 95,
#    'dew_point': 283.08,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 19.09,
#    'wind_deg': 203,
#    'wind_gust': 30,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 0.25}},
#   {'dt': 1709168400,
#    'temp': 283.4,
#    'feels_like': 283.01,
#    'pressure': 1003,
#    'humidity': 97,
#    'dew_point': 282.97,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 3800,
#    'wind_speed': 17.43,
#    'wind_deg': 208,
#    'wind_gust': 27.71,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 1.31}},
#   {'dt': 1709172000,
#    'temp': 282.71,
#    'feels_like': 277.68,
#    'pressure': 1005,
#    'humidity': 98,
#    'dew_point': 282.34,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 6418,
#    'wind_speed': 16.37,
#    'wind_deg': 230,
#    'wind_gust': 26.5,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 3.5}},
#   {'dt': 1709175600,
#    'temp': 282.23,
#    'feels_like': 276.94,
#    'pressure': 1007,
#    'humidity': 92,
#    'dew_point': 281.01,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 6905,
#    'wind_speed': 16.88,
#    'wind_deg': 276,
#    'wind_gust': 23.1,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 1.44}},
#   {'dt': 1709179200,
#    'temp': 278.57,
#    'feels_like': 271.85,
#    'pressure': 1010,
#    'humidity': 85,
#    'dew_point': 276.33,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 9996,
#    'wind_speed': 17,
#    'wind_deg': 283,
#    'wind_gust': 20.91,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 2.69}},
#   {'dt': 1709182800,
#    'temp': 278.21,
#    'feels_like': 271.85,
#    'pressure': 1011,
#    'humidity': 81,
#    'dew_point': 275.22,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 14.24,
#    'wind_deg': 283,
#    'wind_gust': 20.91,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 0.81}},
#   {'dt': 1709186400,
#    'temp': 278.6,
#    'feels_like': 272.01,
#    'pressure': 1013,
#    'humidity': 68,
#    'dew_point': 273.24,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 16.3,
#    'wind_deg': 294,
#    'wind_gust': 18.8,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.8},
#   {'dt': 1709190000,
#    'temp': 277,
#    'feels_like': 270,
#    'pressure': 1015,
#    'humidity': 59,
#    'dew_point': 269.67,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 16.02,
#    'wind_deg': 298,
#    'wind_gust': 18,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.08},
#   {'dt': 1709193600,
#    'temp': 276.02,
#    'feels_like': 269.02,
#    'pressure': 1017,
#    'humidity': 55,
#    'dew_point': 267.94,
#    'uvi': 0,
#    'clouds': 53,
#    'visibility': 10000,
#    'wind_speed': 15.45,
#    'wind_deg': 307,
#    'wind_gust': 17.6,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0.04},
#   {'dt': 1709197200,
#    'temp': 275.34,
#    'feels_like': 268.34,
#    'pressure': 1019,
#    'humidity': 57,
#    'dew_point': 267.62,
#    'uvi': 0,
#    'clouds': 37,
#    'visibility': 10000,
#    'wind_speed': 15.04,
#    'wind_deg': 306,
#    'wind_gust': 16.8,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1709200800,
#    'temp': 274.98,
#    'feels_like': 267.98,
#    'pressure': 1021,
#    'humidity': 56,
#    'dew_point': 267.13,
#    'uvi': 0,
#    'clouds': 30,
#    'visibility': 10000,
#    'wind_speed': 13.88,
#    'wind_deg': 305,
#    'wind_gust': 15.62,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1709204400,
#    'temp': 274.71,
#    'feels_like': 267.71,
#    'pressure': 1022,
#    'humidity': 56,
#    'dew_point': 266.89,
#    'uvi': 0,
#    'clouds': 25,
#    'visibility': 10000,
#    'wind_speed': 12.8,
#    'wind_deg': 301,
#    'wind_gust': 14.82,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1709208000,
#    'temp': 274.65,
#    'feels_like': 267.65,
#    'pressure': 1023,
#    'humidity': 55,
#    'dew_point': 266.6,
#    'uvi': 0.16,
#    'clouds': 35,
#    'visibility': 10000,
#    'wind_speed': 13.17,
#    'wind_deg': 295,
#    'wind_gust': 15.82,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1709211600,
#    'temp': 274.53,
#    'feels_like': 267.53,
#    'pressure': 1025,
#    'humidity': 51,
#    'dew_point': 265.5,
#    'uvi': 0.58,
#    'clouds': 10,
#    'visibility': 10000,
#    'wind_speed': 14.68,
#    'wind_deg': 294,
#    'wind_gust': 17.4,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1709215200,
#    'temp': 274.13,
#    'feels_like': 267.13,
#    'pressure': 1026,
#    'humidity': 49,
#    'dew_point': 264.63,
#    'uvi': 1.37,
#    'clouds': 8,
#    'visibility': 10000,
#    'wind_speed': 15.07,
#    'wind_deg': 300,
#    'wind_gust': 18.1,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1709218800,
#    'temp': 274.1,
#    'feels_like': 267.1,
#    'pressure': 1027,
#    'humidity': 52,
#    'dew_point': 265.45,
#    'uvi': 2.27,
#    'clouds': 7,
#    'visibility': 10000,
#    'wind_speed': 11.98,
#    'wind_deg': 297,
#    'wind_gust': 14.3,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1709222400,
#    'temp': 274.4,
#    'feels_like': 267.4,
#    'pressure': 1027,
#    'humidity': 51,
#    'dew_point': 265.4,
#    'uvi': 2.92,
#    'clouds': 30,
#    'visibility': 10000,
#    'wind_speed': 11.39,
#    'wind_deg': 294,
#    'wind_gust': 13.81,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1709226000,
#    'temp': 274.92,
#    'feels_like': 268.06,
#    'pressure': 1026,
#    'humidity': 49,
#    'dew_point': 265.27,
#    'uvi': 3.09,
#    'clouds': 44,
#    'visibility': 10000,
#    'wind_speed': 11.41,
#    'wind_deg': 292,
#    'wind_gust': 14.6,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1709229600,
#    'temp': 275.7,
#    'feels_like': 269.23,
#    'pressure': 1026,
#    'humidity': 47,
#    'dew_point': 265.6,
#    'uvi': 2.83,
#    'clouds': 54,
#    'visibility': 10000,
#    'wind_speed': 10.93,
#    'wind_deg': 283,
#    'wind_gust': 14.62,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1709233200,
#    'temp': 276.62,
#    'feels_like': 269.95,
#    'pressure': 1026,
#    'humidity': 45,
#    'dew_point': 265.76,
#    'uvi': 2.06,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 13,
#    'wind_deg': 291,
#    'wind_gust': 16.11,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1709236800,
#    'temp': 277.31,
#    'feels_like': 270.91,
#    'pressure': 1026,
#    'humidity': 43,
#    'dew_point': 265.81,
#    'uvi': 1.19,
#    'clouds': 81,
#    'visibility': 10000,
#    'wind_speed': 12.91,
#    'wind_deg': 290,
#    'wind_gust': 17.21,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1709240400,
#    'temp': 277.76,
#    'feels_like': 271.68,
#    'pressure': 1026,
#    'humidity': 42,
#    'dew_point': 266.1,
#    'uvi': 0.47,
#    'clouds': 56,
#    'visibility': 10000,
#    'wind_speed': 12.2,
#    'wind_deg': 292,
#    'wind_gust': 15.2,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1709244000,
#    'temp': 278.11,
#    'feels_like': 272.23,
#    'pressure': 1027,
#    'humidity': 42,
#    'dew_point': 266.22,
#    'uvi': 0,
#    'clouds': 43,
#    'visibility': 10000,
#    'wind_speed': 11.83,
#    'wind_deg': 291,
#    'wind_gust': 13.9,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1709247600,
#    'temp': 278.15,
#    'feels_like': 272.33,
#    'pressure': 1028,
#    'humidity': 42,
#    'dew_point': 266.3,
#    'uvi': 0,
#    'clouds': 34,
#    'visibility': 10000,
#    'wind_speed': 11.65,
#    'wind_deg': 288,
#    'wind_gust': 13.31,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1709251200,
#    'temp': 278.27,
#    'feels_like': 272.48,
#    'pressure': 1029,
#    'humidity': 48,
#    'dew_point': 268.28,
#    'uvi': 0,
#    'clouds': 29,
#    'visibility': 10000,
#    'wind_speed': 11.69,
#    'wind_deg': 288,
#    'wind_gust': 13.31,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0}],
#  'daily': [{'dt': 1709053200,
#    'sunrise': 1709033358,
#    'sunset': 1709073639,
#    'moonrise': 1709085060,
#    'moonset': 1709038320,
#    'moon_phase': 0.6,
#    'temp': {'day': 281.74,
#     'min': 280.28,
#     'max': 282.85,
#     'night': 282.59,
#     'eve': 282.77,
#     'morn': 280.79},
#    'feels_like': {'day': 277.36,
#     'night': 277.96,
#     'eve': 278.33,
#     'morn': 277.38},
#    'pressure': 1017,
#    'humidity': 85,
#    'dew_point': 279.26,
#    'wind_speed': 13.84,
#    'wind_deg': 184,
#    'wind_gust': 24.2,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': 80,
#    'pop': 1,
#    'rain': 3.24,
#    'uvi': 2.55},
#   {'dt': 1709139600,
#    'sunrise': 1709119670,
#    'sunset': 1709160106,
#    'moonrise': 1709175120,
#    'moonset': 1709125860,
#    'moon_phase': 0.63,
#    'temp': {'day': 283.19,
#     'min': 278.57,
#     'max': 283.92,
#     'night': 278.57,
#     'eve': 283.84,
#     'morn': 283.3},
#    'feels_like': {'day': 282.76,
#     'night': 271.85,
#     'eve': 283.45,
#     'morn': 282.93},
#    'pressure': 1008,
#    'humidity': 96,
#    'dew_point': 282.59,
#    'wind_speed': 19.25,
#    'wind_deg': 192,
#    'wind_gust': 32.8,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 1,
#    'rain': 24.23,
#    'uvi': 0.65},
#   {'dt': 1709226000,
#    'sunrise': 1709205981,
#    'sunset': 1709246573,
#    'moonrise': 1709265240,
#    'moonset': 1709213580,
#    'moon_phase': 0.66,
#    'temp': {'day': 274.92,
#     'min': 274.1,
#     'max': 278.6,
#     'night': 277.92,
#     'eve': 278.15,
#     'morn': 274.71},
#    'feels_like': {'day': 268.06,
#     'night': 272.52,
#     'eve': 272.33,
#     'morn': 267.71},
#    'pressure': 1026,
#    'humidity': 49,
#    'dew_point': 265.27,
#    'wind_speed': 16.3,
#    'wind_deg': 294,
#    'wind_gust': 20.91,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 44,
#    'pop': 1,
#    'rain': 0.81,
#    'uvi': 3.09},
#   {'dt': 1709312400,
#    'sunrise': 1709292291,
#    'sunset': 1709333039,
#    'moonrise': 1709355600,
#    'moonset': 1709301540,
#    'moon_phase': 0.69,
#    'temp': {'day': 278.37,
#     'min': 276.95,
#     'max': 280.08,
#     'night': 280.08,
#     'eve': 279.8,
#     'morn': 276.97},
#    'feels_like': {'day': 274.08,
#     'night': 275.99,
#     'eve': 275.26,
#     'morn': 272.91},
#    'pressure': 1034,
#    'humidity': 55,
#    'dew_point': 269.97,
#    'wind_speed': 9.13,
#    'wind_deg': 292,
#    'wind_gust': 13.22,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': 83,
#    'pop': 0,
#    'uvi': 3.75},
#   {'dt': 1709398800,
#    'sunrise': 1709378600,
#    'sunset': 1709419504,
#    'moonrise': 0,
#    'moonset': 1709389800,
#    'moon_phase': 0.72,
#    'temp': {'day': 280.9,
#     'min': 279.99,
#     'max': 280.91,
#     'night': 279.99,
#     'eve': 280.51,
#     'morn': 280.8},
#    'feels_like': {'day': 277.69,
#     'night': 275.49,
#     'eve': 276.13,
#     'morn': 277.41},
#    'pressure': 1023,
#    'humidity': 100,
#    'dew_point': 280.9,
#    'wind_speed': 8.94,
#    'wind_deg': 40,
#    'wind_gust': 12.21,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 1,
#    'rain': 13.57,
#    'uvi': 0.84},
#   {'dt': 1709485200,
#    'sunrise': 1709464909,
#    'sunset': 1709505970,
#    'moonrise': 1709446020,
#    'moonset': 1709478540,
#    'moon_phase': 0.75,
#    'temp': {'day': 280.01,
#     'min': 279.7,
#     'max': 283.34,
#     'night': 283.34,
#     'eve': 280.93,
#     'morn': 279.7},
#    'feels_like': {'day': 277.12,
#     'night': 282.53,
#     'eve': 278.34,
#     'morn': 275.97},
#    'pressure': 1025,
#    'humidity': 95,
#    'dew_point': 279.36,
#    'wind_speed': 8.1,
#    'wind_deg': 6,
#    'wind_gust': 11.9,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 0.52,
#    'rain': 0.62,
#    'uvi': 0.14},
#   {'dt': 1709571600,
#    'sunrise': 1709551216,
#    'sunset': 1709592435,
#    'moonrise': 1709536380,
#    'moonset': 1709567880,
#    'moon_phase': 0.79,
#    'temp': {'day': 281.04,
#     'min': 280.31,
#     'max': 282.81,
#     'night': 281.17,
#     'eve': 282.2,
#     'morn': 280.61},
#    'feels_like': {'day': 279.69,
#     'night': 278.71,
#     'eve': 281.14,
#     'morn': 278.45},
#    'pressure': 1024,
#    'humidity': 89,
#    'dew_point': 279.3,
#    'wind_speed': 4.78,
#    'wind_deg': 20,
#    'wind_gust': 4.8,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': 100,
#    'pop': 0,
#    'uvi': 1},
#   {'dt': 1709658000,
#    'sunrise': 1709637524,
#    'sunset': 1709678899,
#    'moonrise': 1709626500,
#    'moonset': 1709658000,
#    'moon_phase': 0.82,
#    'temp': {'day': 280.94,
#     'min': 280.62,
#     'max': 281.34,
#     'night': 280.83,
#     'eve': 280.98,
#     'morn': 280.62},
#    'feels_like': {'day': 277.9, 'night': 278.58, 'eve': 278.5, 'morn': 277.48},
#    'pressure': 1022,
#    'humidity': 92,
#    'dew_point': 279.7,
#    'wind_speed': 5.37,
#    'wind_deg': 217,
#    'wind_gust': 7.6,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': 86,
#    'pop': 0,
#    'uvi': 1}]}

# %%
# Step 2: Write code here

# %%
# Out:
# <h1>Get 7-Day Forecast</h1>
# interactive(children=(Text(value=' ', continuous_update=False, description='location'), Button(description='Ru…
