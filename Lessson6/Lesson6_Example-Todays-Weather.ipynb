# %% [markdown]
# # Example: Today's Weather
#
# This example will input a location and then output today's current weather conditions at that location.
#
# To complete this example we will use the following API's
#
# - https://www.openstreetmap.org/ Geocode api to get GPS coordinates for a location eg. Syracuse, NY
# - https://openweathermap.org/ forecast api to get the currnt weather conditions for those GPS coordinates

# %%
# Todo list
# input a location eg. Syracuse, ny
# use the google geocode api to get a lat/lng
# use the weather api and lat/lng to get current weather conditions
# output current weather conditions (temperature and summary (rain, snow, etc...))

# %%
import requests

# %%
def geocode(location):
    query_string = {'q' : location, 'format': 'json'}
    headers = { "user-agent" : "ist300 example auramnar@syr.edu" }
    url='https://nominatim.openstreetmap.org/search' 
    response = requests.get(url, params = query_string, headers=headers)
    response.raise_for_status()
    geodata = response.json()
    return geodata
        
# Testing with syracuse, NY 
geocode('Syracuse, NY')
# Out:
# [{'place_id': 8914331,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 174916,
#   'lat': '43.0481221',
#   'lon': '-76.1474244',
#   'class': 'boundary',
#   'type': 'administrative',
#   'place_rank': 14,
#   'importance': 0.5767762857760727,
#   'addresstype': 'city',
#   'name': 'City of Syracuse',
#   'display_name': 'City of Syracuse, Onondaga County, New York, United States',
#   'boundingbox': ['42.9841650', '43.0861210', '-76.2046290', '-76.0742730']}]

# %%
def getweather(lat,lon):
    key = '67f9d45c32dd086df27f2b7a90370a8e' # sign up for your own key at https://openweathermap.org/ 
    query_string = { 'lat' : lat, 'lon': lon, 'appid' : key, 'units' : 'imperial'}
    url='https://api.openweathermap.org/data/2.5/onecall' 
    response = requests.get(url, params=query_string)
    response.raise_for_status()
    #print (response.url)
    weather = response.json()
    return weather

# Testing with syracuse, NY coordinates
getweather( 43.0481221, -76.1474244 )
# Out:
# {'lat': 43.0481,
#  'lon': -76.1474,
#  'timezone': 'America/New_York',
#  'timezone_offset': -18000,
#  'current': {'dt': 1708978503,
#   'sunrise': 1708947992,
#   'sunset': 1708987736,
#   'temp': 51.93,
#   'feels_like': 49.41,
#   'pressure': 1014,
#   'humidity': 55,
#   'dew_point': 36.28,
#   'uvi': 0.96,
#   'clouds': 75,
#   'visibility': 10000,
#   'wind_speed': 10.36,
#   'wind_deg': 310,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}]},
#  'minutely': [{'dt': 1708978560, 'precipitation': 0},
#   {'dt': 1708978620, 'precipitation': 0},
#   {'dt': 1708978680, 'precipitation': 0},
#   {'dt': 1708978740, 'precipitation': 0},
#   {'dt': 1708978800, 'precipitation': 0},
#   {'dt': 1708978860, 'precipitation': 0},
#   {'dt': 1708978920, 'precipitation': 0},
#   {'dt': 1708978980, 'precipitation': 0},
#   {'dt': 1708979040, 'precipitation': 0},
#   {'dt': 1708979100, 'precipitation': 0},
#   {'dt': 1708979160, 'precipitation': 0},
#   {'dt': 1708979220, 'precipitation': 0},
#   {'dt': 1708979280, 'precipitation': 0},
#   {'dt': 1708979340, 'precipitation': 0},
#   {'dt': 1708979400, 'precipitation': 0},
#   {'dt': 1708979460, 'precipitation': 0},
#   {'dt': 1708979520, 'precipitation': 0},
#   {'dt': 1708979580, 'precipitation': 0},
#   {'dt': 1708979640, 'precipitation': 0},
#   {'dt': 1708979700, 'precipitation': 0},
#   {'dt': 1708979760, 'precipitation': 0},
#   {'dt': 1708979820, 'precipitation': 0},
#   {'dt': 1708979880, 'precipitation': 0},
#   {'dt': 1708979940, 'precipitation': 0},
#   {'dt': 1708980000, 'precipitation': 0},
#   {'dt': 1708980060, 'precipitation': 0},
#   {'dt': 1708980120, 'precipitation': 0},
#   {'dt': 1708980180, 'precipitation': 0},
#   {'dt': 1708980240, 'precipitation': 0},
#   {'dt': 1708980300, 'precipitation': 0},
#   {'dt': 1708980360, 'precipitation': 0},
#   {'dt': 1708980420, 'precipitation': 0},
#   {'dt': 1708980480, 'precipitation': 0},
#   {'dt': 1708980540, 'precipitation': 0},
#   {'dt': 1708980600, 'precipitation': 0},
#   {'dt': 1708980660, 'precipitation': 0},
#   {'dt': 1708980720, 'precipitation': 0},
#   {'dt': 1708980780, 'precipitation': 0},
#   {'dt': 1708980840, 'precipitation': 0},
#   {'dt': 1708980900, 'precipitation': 0},
#   {'dt': 1708980960, 'precipitation': 0},
#   {'dt': 1708981020, 'precipitation': 0},
#   {'dt': 1708981080, 'precipitation': 0},
#   {'dt': 1708981140, 'precipitation': 0},
#   {'dt': 1708981200, 'precipitation': 0},
#   {'dt': 1708981260, 'precipitation': 0},
#   {'dt': 1708981320, 'precipitation': 0},
#   {'dt': 1708981380, 'precipitation': 0},
#   {'dt': 1708981440, 'precipitation': 0},
#   {'dt': 1708981500, 'precipitation': 0},
#   {'dt': 1708981560, 'precipitation': 0},
#   {'dt': 1708981620, 'precipitation': 0},
#   {'dt': 1708981680, 'precipitation': 0},
#   {'dt': 1708981740, 'precipitation': 0},
#   {'dt': 1708981800, 'precipitation': 0},
#   {'dt': 1708981860, 'precipitation': 0},
#   {'dt': 1708981920, 'precipitation': 0},
#   {'dt': 1708981980, 'precipitation': 0},
#   {'dt': 1708982040, 'precipitation': 0},
#   {'dt': 1708982100, 'precipitation': 0}],
#  'hourly': [{'dt': 1708977600,
#    'temp': 51.93,
#    'feels_like': 49.41,
#    'pressure': 1014,
#    'humidity': 55,
#    'dew_point': 36.28,
#    'uvi': 0.96,
#    'clouds': 75,
#    'visibility': 10000,
#    'wind_speed': 6.6,
#    'wind_deg': 303,
#    'wind_gust': 9.06,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1708981200,
#    'temp': 50.59,
#    'feels_like': 48.04,
#    'pressure': 1014,
#    'humidity': 57,
#    'dew_point': 35.94,
#    'uvi': 0.37,
#    'clouds': 71,
#    'visibility': 10000,
#    'wind_speed': 5.37,
#    'wind_deg': 329,
#    'wind_gust': 5.88,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1708984800,
#    'temp': 48.11,
#    'feels_like': 46.38,
#    'pressure': 1015,
#    'humidity': 61,
#    'dew_point': 35.31,
#    'uvi': 0.09,
#    'clouds': 69,
#    'visibility': 10000,
#    'wind_speed': 4.43,
#    'wind_deg': 12,
#    'wind_gust': 5.12,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1708988400,
#    'temp': 44.02,
#    'feels_like': 41.61,
#    'pressure': 1015,
#    'humidity': 66,
#    'dew_point': 33.42,
#    'uvi': 0,
#    'clouds': 70,
#    'visibility': 10000,
#    'wind_speed': 4.43,
#    'wind_deg': 57,
#    'wind_gust': 5.48,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1708992000,
#    'temp': 40.37,
#    'feels_like': 36.88,
#    'pressure': 1016,
#    'humidity': 71,
#    'dew_point': 31.77,
#    'uvi': 0,
#    'clouds': 72,
#    'visibility': 10000,
#    'wind_speed': 5.03,
#    'wind_deg': 91,
#    'wind_gust': 7.43,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1708995600,
#    'temp': 37.04,
#    'feels_like': 32.59,
#    'pressure': 1016,
#    'humidity': 78,
#    'dew_point': 29.82,
#    'uvi': 0,
#    'clouds': 98,
#    'visibility': 10000,
#    'wind_speed': 5.5,
#    'wind_deg': 116,
#    'wind_gust': 8.5,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1708999200,
#    'temp': 37.13,
#    'feels_like': 32.22,
#    'pressure': 1016,
#    'humidity': 81,
#    'dew_point': 30.85,
#    'uvi': 0,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 6.17,
#    'wind_deg': 123,
#    'wind_gust': 10.42,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1709002800,
#    'temp': 37.62,
#    'feels_like': 32.4,
#    'pressure': 1016,
#    'humidity': 82,
#    'dew_point': 31.87,
#    'uvi': 0,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 6.8,
#    'wind_deg': 130,
#    'wind_gust': 15.93,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1709006400,
#    'temp': 38.39,
#    'feels_like': 33.1,
#    'pressure': 1014,
#    'humidity': 82,
#    'dew_point': 32.67,
#    'uvi': 0,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 7.16,
#    'wind_deg': 140,
#    'wind_gust': 16.96,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1709010000,
#    'temp': 39.38,
#    'feels_like': 34.07,
#    'pressure': 1014,
#    'humidity': 81,
#    'dew_point': 33.37,
#    'uvi': 0,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 7.56,
#    'wind_deg': 148,
#    'wind_gust': 21.72,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1709013600,
#    'temp': 40.64,
#    'feels_like': 35.24,
#    'pressure': 1013,
#    'humidity': 80,
#    'dew_point': 33.93,
#    'uvi': 0,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 8.25,
#    'wind_deg': 154,
#    'wind_gust': 24.29,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1709017200,
#    'temp': 42.06,
#    'feels_like': 36.45,
#    'pressure': 1013,
#    'humidity': 79,
#    'dew_point': 35.02,
#    'uvi': 0,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 9.42,
#    'wind_deg': 162,
#    'wind_gust': 27.2,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1709020800,
#    'temp': 42.28,
#    'feels_like': 36.63,
#    'pressure': 1013,
#    'humidity': 80,
#    'dew_point': 35.65,
#    'uvi': 0,
#    'clouds': 86,
#    'visibility': 10000,
#    'wind_speed': 9.62,
#    'wind_deg': 163,
#    'wind_gust': 28.07,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1709024400,
#    'temp': 42.64,
#    'feels_like': 36.75,
#    'pressure': 1012,
#    'humidity': 79,
#    'dew_point': 35.74,
#    'uvi': 0,
#    'clouds': 78,
#    'visibility': 10000,
#    'wind_speed': 10.38,
#    'wind_deg': 165,
#    'wind_gust': 29.71,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1709028000,
#    'temp': 43.07,
#    'feels_like': 36.84,
#    'pressure': 1012,
#    'humidity': 79,
#    'dew_point': 36.01,
#    'uvi': 0,
#    'clouds': 79,
#    'visibility': 10000,
#    'wind_speed': 11.63,
#    'wind_deg': 166,
#    'wind_gust': 31.21,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1709031600,
#    'temp': 43.27,
#    'feels_like': 36.91,
#    'pressure': 1011,
#    'humidity': 80,
#    'dew_point': 36.59,
#    'uvi': 0,
#    'clouds': 67,
#    'visibility': 10000,
#    'wind_speed': 12.12,
#    'wind_deg': 163,
#    'wind_gust': 32.84,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1709035200,
#    'temp': 44.1,
#    'feels_like': 37.62,
#    'pressure': 1011,
#    'humidity': 80,
#    'dew_point': 37.56,
#    'uvi': 0,
#    'clouds': 59,
#    'visibility': 10000,
#    'wind_speed': 13.15,
#    'wind_deg': 162,
#    'wind_gust': 34.78,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1709038800,
#    'temp': 45.79,
#    'feels_like': 39.85,
#    'pressure': 1011,
#    'humidity': 78,
#    'dew_point': 38.62,
#    'uvi': 0.34,
#    'clouds': 21,
#    'visibility': 10000,
#    'wind_speed': 12.91,
#    'wind_deg': 165,
#    'wind_gust': 35.25,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1709042400,
#    'temp': 49.15,
#    'feels_like': 43.88,
#    'pressure': 1010,
#    'humidity': 74,
#    'dew_point': 40.39,
#    'uvi': 0.86,
#    'clouds': 16,
#    'visibility': 10000,
#    'wind_speed': 13.71,
#    'wind_deg': 165,
#    'wind_gust': 35.28,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1709046000,
#    'temp': 52.77,
#    'feels_like': 50.99,
#    'pressure': 1010,
#    'humidity': 69,
#    'dew_point': 42.12,
#    'uvi': 1.54,
#    'clouds': 12,
#    'visibility': 10000,
#    'wind_speed': 14.05,
#    'wind_deg': 165,
#    'wind_gust': 34.49,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1709049600,
#    'temp': 55.83,
#    'feels_like': 54.21,
#    'pressure': 1009,
#    'humidity': 66,
#    'dew_point': 43.75,
#    'uvi': 2.1,
#    'clouds': 19,
#    'visibility': 10000,
#    'wind_speed': 15.88,
#    'wind_deg': 169,
#    'wind_gust': 34.72,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1709053200,
#    'temp': 58.96,
#    'feels_like': 57.52,
#    'pressure': 1008,
#    'humidity': 63,
#    'dew_point': 45.5,
#    'uvi': 2.32,
#    'clouds': 18,
#    'visibility': 10000,
#    'wind_speed': 15.79,
#    'wind_deg': 166,
#    'wind_gust': 30.69,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1709056800,
#    'temp': 61.09,
#    'feels_like': 59.72,
#    'pressure': 1007,
#    'humidity': 60,
#    'dew_point': 46.42,
#    'uvi': 2.08,
#    'clouds': 23,
#    'visibility': 10000,
#    'wind_speed': 15.7,
#    'wind_deg': 173,
#    'wind_gust': 29.48,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1709060400,
#    'temp': 61.88,
#    'feels_like': 60.58,
#    'pressure': 1006,
#    'humidity': 60,
#    'dew_point': 46.96,
#    'uvi': 1.56,
#    'clouds': 18,
#    'visibility': 10000,
#    'wind_speed': 15.35,
#    'wind_deg': 171,
#    'wind_gust': 29.08,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'pop': 0.07},
#   {'dt': 1709064000,
#    'temp': 61.23,
#    'feels_like': 59.97,
#    'pressure': 1006,
#    'humidity': 62,
#    'dew_point': 47.43,
#    'uvi': 0.88,
#    'clouds': 56,
#    'visibility': 10000,
#    'wind_speed': 14.43,
#    'wind_deg': 170,
#    'wind_gust': 29.33,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0.07},
#   {'dt': 1709067600,
#    'temp': 59.41,
#    'feels_like': 58.15,
#    'pressure': 1005,
#    'humidity': 66,
#    'dew_point': 47.03,
#    'uvi': 0.35,
#    'clouds': 70,
#    'visibility': 10000,
#    'wind_speed': 16.58,
#    'wind_deg': 171,
#    'wind_gust': 31.7,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0.02},
#   {'dt': 1709071200,
#    'temp': 56.73,
#    'feels_like': 55.31,
#    'pressure': 1006,
#    'humidity': 68,
#    'dew_point': 45.48,
#    'uvi': 0.08,
#    'clouds': 78,
#    'visibility': 10000,
#    'wind_speed': 18.19,
#    'wind_deg': 178,
#    'wind_gust': 33.17,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0.03},
#   {'dt': 1709074800,
#    'temp': 54.28,
#    'feels_like': 52.79,
#    'pressure': 1006,
#    'humidity': 72,
#    'dew_point': 44.73,
#    'uvi': 0,
#    'clouds': 82,
#    'visibility': 10000,
#    'wind_speed': 16.6,
#    'wind_deg': 181,
#    'wind_gust': 35.79,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0.11},
#   {'dt': 1709078400,
#    'temp': 53.4,
#    'feels_like': 52.02,
#    'pressure': 1006,
#    'humidity': 76,
#    'dew_point': 45.25,
#    'uvi': 0,
#    'clouds': 85,
#    'visibility': 10000,
#    'wind_speed': 16.75,
#    'wind_deg': 177,
#    'wind_gust': 34.74,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.12},
#   {'dt': 1709082000,
#    'temp': 52.41,
#    'feels_like': 51.12,
#    'pressure': 1005,
#    'humidity': 80,
#    'dew_point': 45.66,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 16.84,
#    'wind_deg': 178,
#    'wind_gust': 34.65,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.04},
#   {'dt': 1709085600,
#    'temp': 52.32,
#    'feels_like': 51.15,
#    'pressure': 1005,
#    'humidity': 83,
#    'dew_point': 46.38,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 16.69,
#    'wind_deg': 184,
#    'wind_gust': 35.41,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1709089200,
#    'temp': 52.23,
#    'feels_like': 51.1,
#    'pressure': 1005,
#    'humidity': 84,
#    'dew_point': 46.69,
#    'uvi': 0,
#    'clouds': 96,
#    'visibility': 10000,
#    'wind_speed': 16.6,
#    'wind_deg': 188,
#    'wind_gust': 34.94,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1709092800,
#    'temp': 52.34,
#    'feels_like': 51.28,
#    'pressure': 1004,
#    'humidity': 85,
#    'dew_point': 46.99,
#    'uvi': 0,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 17.16,
#    'wind_deg': 187,
#    'wind_gust': 35.61,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1709096400,
#    'temp': 52.79,
#    'feels_like': 51.76,
#    'pressure': 1003,
#    'humidity': 85,
#    'dew_point': 47.7,
#    'uvi': 0,
#    'clouds': 92,
#    'visibility': 10000,
#    'wind_speed': 16.06,
#    'wind_deg': 180,
#    'wind_gust': 35.54,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1709100000,
#    'temp': 52.45,
#    'feels_like': 51.53,
#    'pressure': 1002,
#    'humidity': 88,
#    'dew_point': 48.11,
#    'uvi': 0,
#    'clouds': 94,
#    'visibility': 10000,
#    'wind_speed': 15.5,
#    'wind_deg': 171,
#    'wind_gust': 35.37,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1709103600,
#    'temp': 53.19,
#    'feels_like': 52.29,
#    'pressure': 1001,
#    'humidity': 87,
#    'dew_point': 48.72,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 16.87,
#    'wind_deg': 172,
#    'wind_gust': 38.16,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1709107200,
#    'temp': 53.67,
#    'feels_like': 52.88,
#    'pressure': 999,
#    'humidity': 88,
#    'dew_point': 49.46,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 17.2,
#    'wind_deg': 166,
#    'wind_gust': 39.03,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.1},
#   {'dt': 1709110800,
#    'temp': 54.19,
#    'feels_like': 53.35,
#    'pressure': 998,
#    'humidity': 86,
#    'dew_point': 49.26,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 18.43,
#    'wind_deg': 166,
#    'wind_gust': 41.34,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.88,
#    'rain': {'1h': 0.57}},
#   {'dt': 1709114400,
#    'temp': 54.37,
#    'feels_like': 53.51,
#    'pressure': 996,
#    'humidity': 85,
#    'dew_point': 49.26,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 21.16,
#    'wind_deg': 170,
#    'wind_gust': 43.11,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 2.83}},
#   {'dt': 1709118000,
#    'temp': 55.04,
#    'feels_like': 54.14,
#    'pressure': 995,
#    'humidity': 83,
#    'dew_point': 49.32,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 22.17,
#    'wind_deg': 178,
#    'wind_gust': 46.06,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 0.5}},
#   {'dt': 1709121600,
#    'temp': 56.32,
#    'feels_like': 55.45,
#    'pressure': 995,
#    'humidity': 81,
#    'dew_point': 49.89,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 26.04,
#    'wind_deg': 186,
#    'wind_gust': 49.73,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 1,
#    'rain': {'1h': 0.1}},
#   {'dt': 1709125200,
#    'temp': 58.05,
#    'feels_like': 57.31,
#    'pressure': 995,
#    'humidity': 80,
#    'dew_point': 50.99,
#    'uvi': 0.03,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 23.53,
#    'wind_deg': 192,
#    'wind_gust': 47.94,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.25},
#   {'dt': 1709128800,
#    'temp': 58.3,
#    'feels_like': 57.6,
#    'pressure': 995,
#    'humidity': 80,
#    'dew_point': 51.22,
#    'uvi': 0.52,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 24.27,
#    'wind_deg': 193,
#    'wind_gust': 44.47,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.17},
#   {'dt': 1709132400,
#    'temp': 59.7,
#    'feels_like': 59.09,
#    'pressure': 995,
#    'humidity': 79,
#    'dew_point': 52.25,
#    'uvi': 1.2,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 25.03,
#    'wind_deg': 192,
#    'wind_gust': 43.93,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.16},
#   {'dt': 1709136000,
#    'temp': 61.18,
#    'feels_like': 60.57,
#    'pressure': 994,
#    'humidity': 76,
#    'dew_point': 52.65,
#    'uvi': 1.2,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 24.09,
#    'wind_deg': 193,
#    'wind_gust': 43.82,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.13},
#   {'dt': 1709139600,
#    'temp': 60.12,
#    'feels_like': 59.59,
#    'pressure': 993,
#    'humidity': 80,
#    'dew_point': 53.11,
#    'uvi': 0.92,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 22.93,
#    'wind_deg': 185,
#    'wind_gust': 39.59,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.18},
#   {'dt': 1709143200,
#    'temp': 59.99,
#    'feels_like': 59.45,
#    'pressure': 991,
#    'humidity': 80,
#    'dew_point': 52.99,
#    'uvi': 0.67,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 23.8,
#    'wind_deg': 185,
#    'wind_gust': 43.17,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.26},
#   {'dt': 1709146800,
#    'temp': 59.92,
#    'feels_like': 59.41,
#    'pressure': 992,
#    'humidity': 81,
#    'dew_point': 53.19,
#    'uvi': 0.65,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 24.47,
#    'wind_deg': 204,
#    'wind_gust': 47.36,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.92,
#    'rain': {'1h': 0.62}}],
#  'daily': [{'dt': 1708966800,
#    'sunrise': 1708947992,
#    'sunset': 1708987736,
#    'moonrise': 1708995900,
#    'moonset': 1708951560,
#    'moon_phase': 0.57,
#    'temp': {'day': 47.86,
#     'min': 35.11,
#     'max': 51.93,
#     'night': 38.39,
#     'eve': 44.02,
#     'morn': 36.7},
#    'feels_like': {'day': 43.86, 'night': 33.1, 'eve': 41.61, 'morn': 30.51},
#    'pressure': 1015,
#    'humidity': 60,
#    'dew_point': 34.66,
#    'wind_speed': 12.41,
#    'wind_deg': 199,
#    'wind_gust': 30.44,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': 56,
#    'pop': 0.18,
#    'uvi': 1.94},
#   {'dt': 1709053200,
#    'sunrise': 1709034296,
#    'sunset': 1709074212,
#    'moonrise': 1709086020,
#    'moonset': 1709038980,
#    'moon_phase': 0.6,
#    'temp': {'day': 58.96,
#     'min': 39.38,
#     'max': 61.88,
#     'night': 52.34,
#     'eve': 54.28,
#     'morn': 43.27},
#    'feels_like': {'day': 57.52, 'night': 51.28, 'eve': 52.79, 'morn': 36.91},
#    'pressure': 1008,
#    'humidity': 63,
#    'dew_point': 45.5,
#    'wind_speed': 18.19,
#    'wind_deg': 178,
#    'wind_gust': 35.79,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': 18,
#    'pop': 0.12,
#    'uvi': 2.32},
#   {'dt': 1709139600,
#    'sunrise': 1709120599,
#    'sunset': 1709160688,
#    'moonrise': 1709176200,
#    'moonset': 1709126400,
#    'moon_phase': 0.63,
#    'temp': {'day': 60.12,
#     'min': 25.3,
#     'max': 61.18,
#     'night': 25.3,
#     'eve': 35.08,
#     'morn': 55.04},
#    'feels_like': {'day': 59.59, 'night': 12.7, 'eve': 24.17, 'morn': 54.14},
#    'pressure': 993,
#    'humidity': 80,
#    'dew_point': 53.11,
#    'wind_speed': 26.04,
#    'wind_deg': 186,
#    'wind_gust': 49.73,
#    'weather': [{'id': 616,
#      'main': 'Snow',
#      'description': 'rain and snow',
#      'icon': '13d'}],
#    'clouds': 100,
#    'pop': 1,
#    'rain': 13.97,
#    'snow': 1.34,
#    'uvi': 1.2},
#   {'dt': 1709226000,
#    'sunrise': 1709206901,
#    'sunset': 1709247163,
#    'moonrise': 1709266500,
#    'moonset': 1709214000,
#    'moon_phase': 0.66,
#    'temp': {'day': 30.34,
#     'min': 23.41,
#     'max': 31.1,
#     'night': 27.61,
#     'eve': 28.22,
#     'morn': 23.41},
#    'feels_like': {'day': 18.25, 'night': 18.86, 'eve': 18.73, 'morn': 10.81},
#    'pressure': 1027,
#    'humidity': 54,
#    'dew_point': 14.5,
#    'wind_speed': 19.69,
#    'wind_deg': 286,
#    'wind_gust': 37.89,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': 97,
#    'pop': 0.46,
#    'snow': 3.11,
#    'uvi': 2.17},
#   {'dt': 1709312400,
#    'sunrise': 1709293202,
#    'sunset': 1709333638,
#    'moonrise': 0,
#    'moonset': 1709301780,
#    'moon_phase': 0.69,
#    'temp': {'day': 47.68,
#     'min': 27.77,
#     'max': 47.68,
#     'night': 39.4,
#     'eve': 40.91,
#     'morn': 29.39},
#    'feels_like': {'day': 42.93, 'night': 32.9, 'eve': 33.44, 'morn': 22.32},
#    'pressure': 1024,
#    'humidity': 40,
#    'dew_point': 24.13,
#    'wind_speed': 13.62,
#    'wind_deg': 195,
#    'wind_gust': 30.51,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': 54,
#    'pop': 0,
#    'uvi': 3.17},
#   {'dt': 1709398800,
#    'sunrise': 1709379502,
#    'sunset': 1709420113,
#    'moonrise': 1709356980,
#    'moonset': 1709389920,
#    'moon_phase': 0.72,
#    'temp': {'day': 42.49,
#     'min': 38.25,
#     'max': 44.73,
#     'night': 40.95,
#     'eve': 41.65,
#     'morn': 38.35},
#    'feels_like': {'day': 42.49, 'night': 40.95, 'eve': 41.65, 'morn': 35.2},
#    'pressure': 1022,
#    'humidity': 87,
#    'dew_point': 38.1,
#    'wind_speed': 8.28,
#    'wind_deg': 174,
#    'wind_gust': 20.92,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 0.55,
#    'rain': 0.59,
#    'uvi': 4},
#   {'dt': 1709485200,
#    'sunrise': 1709465801,
#    'sunset': 1709506587,
#    'moonrise': 1709447580,
#    'moonset': 1709478540,
#    'moon_phase': 0.75,
#    'temp': {'day': 51.66,
#     'min': 40.77,
#     'max': 52.9,
#     'night': 43.88,
#     'eve': 46.31,
#     'morn': 41},
#    'feels_like': {'day': 49.39, 'night': 40.06, 'eve': 43.47, 'morn': 41},
#    'pressure': 1030,
#    'humidity': 61,
#    'dew_point': 37.74,
#    'wind_speed': 6.55,
#    'wind_deg': 116,
#    'wind_gust': 14.25,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': 64,
#    'pop': 0,
#    'uvi': 4},
#   {'dt': 1709571600,
#    'sunrise': 1709552100,
#    'sunset': 1709593061,
#    'moonrise': 1709538000,
#    'moonset': 1709567820,
#    'moon_phase': 0.79,
#    'temp': {'day': 56.14,
#     'min': 42.75,
#     'max': 56.14,
#     'night': 44.47,
#     'eve': 48.2,
#     'morn': 42.75},
#    'feels_like': {'day': 54.09, 'night': 37.38, 'eve': 42.21, 'morn': 37.49},
#    'pressure': 1030,
#    'humidity': 56,
#    'dew_point': 39.67,
#    'wind_speed': 15.9,
#    'wind_deg': 158,
#    'wind_gust': 38.05,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': 15,
#    'pop': 0,
#    'uvi': 4}]}

# %%
# then test them here to figure out how to extract from the dictionary
geodata = geocode('Syracuse, NY')
lat = geodata[0]['lat']
lon = geodata[0]['lon']
weather = getweather(lat, lon)
weather.keys()
# Out:
# dict_keys(['lat', 'lon', 'timezone', 'timezone_offset', 'current', 'minutely', 'hourly', 'daily'])

# %%
weather['daily'][0]
# Out:
# {'dt': 1708966800,
#  'sunrise': 1708947992,
#  'sunset': 1708987736,
#  'moonrise': 1708995900,
#  'moonset': 1708951560,
#  'moon_phase': 0.57,
#  'temp': {'day': 47.86,
#   'min': 35.11,
#   'max': 51.93,
#   'night': 38.39,
#   'eve': 44.02,
#   'morn': 36.7},
#  'feels_like': {'day': 43.86, 'night': 33.1, 'eve': 41.61, 'morn': 30.51},
#  'pressure': 1015,
#  'humidity': 60,
#  'dew_point': 34.66,
#  'wind_speed': 12.41,
#  'wind_deg': 199,
#  'wind_gust': 30.44,
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'clouds': 56,
#  'pop': 0.18,
#  'uvi': 1.94}

# %%
import requests
# Now I can write the entire program...
location = input("Where are you? (eg. Syracuse, NY) : ")
geodata = geocode(location)
lat,lon = geodata[0]['lat'], geodata[0]['lon']
weather = getweather(lat,lon)
current = weather['current']
print(f"Current conditions in {location} are {current['weather'][0]['description']} with a temperature of {current['temp']} degrees.")
# Out:
# Where are you? (eg. Syracuse, NY) :  Syracuse, NY
# Current conditions in Syracuse, NY are broken clouds with a temperature of 51.93 degrees.

# %%
from IPython.display import display, HTML
from ipywidgets import interact_manual
import requests

display(HTML("<h1>Weather Forecaster</h1>"))
@interact_manual(location="")
def main(location):
    geodata = geocode(location)
    lat, lon = geodata[0]['lat'], geodata[0]['lon']
    weather = getweather(lat,lon)
    current = weather['current']
    print(f"Current conditions in {location} are {current['weather'][0]['description']} with a temperature of {current['temp']} degrees.")
# Out:
# <h1>Weather Forecaster</h1>
# interactive(children=(Text(value='', continuous_update=False, description='location'), Button(description='Run…
